# %% [markdown]
# # 🐍 Python Basics for Machine Learning

# %% [markdown]
# ## 1. Data Types & Structures

# %%
my_list = [1, 2, 3]
my_dict = {'a': 1, 'b': 2}
my_set = {1, 2, 3}
my_tuple = (1, 2, 3)

# %% [markdown]
# ## 2. List Comprehensions

# %%
squares = [x**2 for x in range(5)]
print(squares)

# %% [markdown]
# ## 3. Functions

# %%
def greet(name):
    return f'Hello {name}'
add = lambda x, y: x + y

# %% [markdown]
# ## 4. File I/O

# %%
with open('test.txt', 'w') as f:
    f.write('Hello World')
with open('test.txt', 'r') as f:
    print(f.read())

# %% [markdown]
# ## 5. Practice Exercises

# %%
# Exercise 1: Create a function that returns the even numbers from a list
